# %% [markdown]
# # Part I 爬蟲
#
# TechOrange爬蟲

# %% [markdown]
# # Part II 文字雲

# %%
import os
import pickle
import jieba
import operator
import numpy as np
from collections import Counter
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from modules import *
font_path = '../tools/msjh.ttc'
font = font_manager.FontProperties(fname='../tools/msjh.ttc',
                                   weight='bold',
                                   style='normal', size=16)

# %%
with open('../data/techorange.pkl', 'rb') as f:
    data = pickle.load(f)
    
data = data[::-1]
contents = [news['content'] for news in data]

# %%
ten_wc = get_wordcloud_of_keywords(['人工智慧','AI'], contents, '../images/circle.png')
ten_wc.to_image()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/y9/vfmh1hx93jj2rp98mgt85dl00000gn/T/jieba.cache
# Loading model cost 0.681 seconds.
# Prefix dict has been built succesfully.
# 8897
# <PIL.Image.Image image mode=RGB size=500x500 at 0x102FB7F98>
